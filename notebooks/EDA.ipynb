# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append(r'C:\Users\User\Downloads\film\Risk-Profiling-And-Predictive-Analytics-for-Car-Insurance\src')
from eda_preprocessing import summarize_data, assess_data_quality, preprocess_data, detect_outliers,check_skewness
from eda_analysis import univariate_analysis, bivariate_analysis, data_comparison, creative_visualizations

# %%
data=pd.read_csv("C:\\Users\\User\\Downloads\\film\\10aca dataset\\MachineLearningRating_v3.txt",delimiter='|',low_memory=False)

# %%
data.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
describe,dtype,info = summarize_data(data)

# %%
describe
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
dtype
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
info
# Out:
# "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 1000098 entries, 0 to 1000097\nData columns (total 52 columns):\n #   Column                    Non-Null Count    Dtype  \n---  ------                    --------------    -----  \n 0   UnderwrittenCoverID       1000098 non-null  int64  \n 1   PolicyID                  1000098 non-null  int64  \n 2   TransactionMonth          1000098 non-null  object \n 3   IsVATRegistered           1000098 non-null  bool   \n 4   Citizenship               1000098 non-null  object \n 5   LegalType                 1000098 non-null  object \n 6   Title                     1000098 non-null  object \n 7   Language                  1000098 non-null  object \n 8   Bank                      854137 non-null   object \n 9   AccountType               959866 non-null   object \n 10  MaritalStatus             991839 non-null   object \n 11  Gender                    990562 non-null   object \n 12  Country                   1000098 non-null  object \n 13  Provin
# ...

# %%
assess_data_quality(data)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
preprocess_data(data)
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
assess_data_quality(data)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                              0
# AccountType                       0
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                            0
# VehicleType                       0
# RegistrationYear                  0
# make                              0
# Model                             0
# Cylinders                         0
# cubiccapacity                     0
# kilowatts                         0
# ...

# %%
data["NumberOfVehiclesInFleet"].isnull().sum(),data.shape
# Out:
# (1000098, (1000098, 52))

# %% [markdown]
# ### The column **NumberOfVehiclesInFleet** has no entries in any of its rows, so I will drop the entire column

# %%
data=data.drop(columns="NumberOfVehiclesInFleet",axis=0)

# %%
assess_data_quality(data)
# Out:
# UnderwrittenCoverID         0
# PolicyID                    0
# TransactionMonth            0
# IsVATRegistered             0
# Citizenship                 0
# LegalType                   0
# Title                       0
# Language                    0
# Bank                        0
# AccountType                 0
# MaritalStatus               0
# Gender                      0
# Country                     0
# Province                    0
# PostalCode                  0
# MainCrestaZone              0
# SubCrestaZone               0
# ItemType                    0
# mmcode                      0
# VehicleType                 0
# RegistrationYear            0
# make                        0
# Model                       0
# Cylinders                   0
# cubiccapacity               0
# kilowatts                   0
# bodytype                    0
# NumberOfDoors               0
# VehicleIntroDate            0
# CustomValueEstimate         0
# AlarmImmobiliser            0
# ...

# %%
check_skewness(data)
# Out:
# UnderwrittenCoverID           0.611710
# PolicyID                      0.737428
# PostalCode                    0.799472
# mmcode                       -2.609955
# RegistrationYear             -0.794487
# Cylinders                     5.706210
# cubiccapacity                 3.577012
# kilowatts                     0.244786
# NumberOfDoors                -2.532027
# CustomValueEstimate          87.049875
# SumInsured                    2.548565
# CalculatedPremiumPerTerm    122.974581
# TotalPremium                138.596458
# TotalClaims                  69.933118
# dtype: float64

# %%
detect_outliers(data)

# %%
univariate_analysis(data)

# %%
bivariate_analysis(data)

# %%
data_comparison(data)

# %%
creative_visualizations(data)
